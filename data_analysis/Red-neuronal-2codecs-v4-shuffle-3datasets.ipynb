# %% [markdown]
# Nou còdec: lz4
#
# Còdecs: blosclz, zstd i lz4
#
# CONCLUSIONS: blosclz sempre és millor que lz4. Llevem blosclz
#
# Còdecs: zstd i lz4

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import aux_funcs
from pathlib import Path

# %% [markdown]
# ## Collect data from 3 different containers
#
# 30: entropy shuffle (split)
#
# 0: zstd shuffle split
#
# 1: lz4 shuffle split

# %%
paths = [Path('../data_inputs_temp/'),
         Path('../data_inputs'),
         Path('../data_inputs_wind/')]

files = ['entropy-shuffle', 'zstd-shuffle-split', 'lz4-shuffle-split']
categories = ["30", "0", "1"]

df_entropy = aux_funcs.get_df_by_category(paths, files[0], categories[0])
df_zstd = aux_funcs.get_df_by_category(paths, files[1], categories[1])
df_lz4 = aux_funcs.get_df_by_category(paths, files[2], categories[2])

# %% [markdown]
# # Filter data
#
# Delete data corresponding to special values chunks.

# %%
df_shuffle = pd.concat([df_zstd, df_lz4, df_entropy], axis=1)
df_shuffle = aux_funcs.delete_special_vals(df_shuffle, ["special_vals0", "special_vals1", "special_vals30"])
df_input_x = df_shuffle.iloc[:, [6, 7]]

# %% [markdown]
# ## Compute best category

# %%
df_codecs = df_shuffle.drop(['cratio30', 'speed30', 'special_vals30', 'special_vals0', 'special_vals1'], axis=1)

# %% [markdown]
# ### Normalize cratio and speed

# %%
dfcratios = pd.concat([df_codecs.iloc[:, 0], df_codecs.iloc[:, 2]], axis=0)
mean_cratio = dfcratios.mean()

cratio0 = df_codecs["cratio0"]
cratio1 = df_codecs["cratio1"]

ncratio0 = cratio0 - mean_cratio
ncratio1 = cratio1 - mean_cratio
all_cratios = np.concatenate((ncratio0, ncratio1), axis=0)

std_cratio = all_cratios.std()
ncratio0 /= std_cratio
ncratio1 /= std_cratio

# %%
dfspeeds = pd.concat([df_codecs.iloc[:, 1], df_codecs.iloc[:, 3]], axis =0)
mean_speed = dfspeeds.mean()

speed0 = df_codecs["speed0"]
speed1 = df_codecs["speed1"]

nspeed0 = speed0 - mean_speed
nspeed1 = speed1 - mean_speed
all_speeds = np.concatenate((nspeed0, nspeed1), axis=0)

dsv_speed = all_speeds.std()
nspeed0 /= dsv_speed
nspeed1 /= dsv_speed

# %% [markdown]
# ### Compute score to determine which category is the best one

# %%
theta = 0.95

df_score = pd.DataFrame()
df_score.insert(0, 0, theta*ncratio0 + (1-theta)*nspeed0)
df_score.insert(1, 1, theta*ncratio1 + (1-theta)*nspeed1)

# %%
best_categ_shuffle = pd.DataFrame(df_score.idxmax(axis=1), columns=['best_categ'])

# %%
categories = best_categ_shuffle['best_categ'].unique()
if len(categories) <= 1:
    raise ValueError("To train the data at least two possible categories must be provided")

# %%
df_t = pd.DataFrame()
df_t = pd.concat([df_t, df_input_x['cratio30']], axis=1)
df_t = pd.concat([df_t, df_input_x['speed30']], axis=1)
df_t = pd.concat([df_t, best_categ_shuffle], axis=1)

# %% [markdown]
# ## Split data into training and test
#
# Create a balanced training data with same amount of samples for each (best) category

# %%
df_blc = pd.DataFrame()
df_test = pd.DataFrame()
nsamples = min(len(df_t[df_t['best_categ'] == categories[0]]),
               len(df_t[df_t['best_categ'] == categories[1]])) - 2000
if nsamples <= 0:
    raise RuntimeError("not enough data")
for i in categories:
    df_i = df_t[df_t['best_categ'] == i]
    df_blc = pd.concat([df_blc, df_i.head(n=nsamples)], axis=0)
    df_test = pd.concat([df_test, df_i.iloc[nsamples:, :]], axis=0)

# %%
dftrain_y = df_blc['best_categ']
dftrain_x = df_blc.drop(['best_categ'], axis=1)

# %%
dftest_y = df_test['best_categ']
dftest_x = df_test.drop(['best_categ'], axis=1)

# %% [markdown]
# ## Normalize entropy data

# %%
dfcratios = dftrain_x.iloc[:, 0]
mean_cratio = dfcratios.mean()

cratio = dftrain_x["cratio30"]
cratio_mean = cratio.mean()
ncratio = cratio - cratio_mean
dsv_cratio = ncratio.std()
ncratio /= dsv_cratio

# %%
dfspeeds = dftrain_x.iloc[:, 1]
mean_speed = dfspeeds.mean()

speed = dftrain_x["speed30"]
speed_mean = speed.mean()
nspeed = speed - speed_mean
dvs_speed = nspeed.std()
nspeed /= dvs_speed

# %%
dftrain_x_norm = pd.DataFrame()
dftrain_x_norm.insert(0, "ncratio", ncratio)
dftrain_x_norm.insert(1, "nspeed", nspeed)
dftrain_x = dftrain_x_norm

# Normalize test data with train statistics
cratio_test = dftest_x["cratio30"]
speed_test = dftest_x["speed30"]
ncratio_test = cratio_test - cratio_mean
ncratio_test /= dsv_cratio
nspeed_test = speed_test - speed_mean
nspeed_test /= dvs_speed

dftest_x_norm = pd.DataFrame()
dftest_x_norm.insert(0, "ncratio", ncratio_test)
dftest_x_norm.insert(1, "nspeed", nspeed_test)

# %% [markdown]
# # Neural Network with 2 categories
#
# ## Build model

# %%
from keras.utils import to_categorical
dftrain_y = to_categorical(dftrain_y)
dftest_y = to_categorical(dftest_y)
# Out:
# 2023-01-02 10:57:29.715973: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from keras import models, layers
import tensorflow

tensorflow.random.set_seed(100)

model = models.Sequential()
model.add(layers.Dense(2, activation='relu', input_shape=(2,)))
model.add(layers.Dense(25, activation='relu'))
model.add(layers.Dense(2, activation='softmax'))
# Out:
# 2023-01-02 10:57:35.264409: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['acc'])

# %% [markdown]
# ## Train it with data

# %%
history = model.fit(dftrain_x, dftrain_y, epochs=35, validation_split=0.1)
# Out:
# Epoch 1/35
# 1759/1759 [==============================] - 5s 2ms/step - loss: 0.4464 - acc: 0.7912 - val_loss: 0.2030 - val_acc: 0.9746
# Epoch 2/35
# 1759/1759 [==============================] - 3s 2ms/step - loss: 0.3725 - acc: 0.8349 - val_loss: 0.1820 - val_acc: 0.9779
# Epoch 3/35
# 1759/1759 [==============================] - 3s 2ms/step - loss: 0.3691 - acc: 0.8357 - val_loss: 0.1860 - val_acc: 0.9835
# Epoch 4/35
# 1759/1759 [==============================] - 3s 2ms/step - loss: 0.3659 - acc: 0.8359 - val_loss: 0.1893 - val_acc: 0.9754
# Epoch 5/35
# 1759/1759 [==============================] - 3s 1ms/step - loss: 0.3626 - acc: 0.8364 - val_loss: 0.2068 - val_acc: 0.9781
# Epoch 6/35
# 1759/1759 [==============================] - 4s 2ms/step - loss: 0.3593 - acc: 0.8370 - val_loss: 0.2031 - val_acc: 0.9775
# Epoch 7/35
# 1759/1759 [==============================] - 3s 2ms/step - loss: 0.3551 - acc: 0.8387 - val_loss: 0.2035 - val_acc: 0.9754
# Epoch 8/35
# 1759/1759 [==============================] - 3s 2ms/step - loss: 0.3510 - acc: 0.8387 - val_loss: 0.1979 - val_acc: 0.9722
# Epoch 9/35
# 1759/1759 [==============================] - 3s 2ms/step - loss: 0.3467 - acc: 0.8414 - val_loss: 0.1758 - val_acc: 0.9811
# Epoch 10/35
# 1759/1759 [==============================] - 2s 1ms/step - loss: 0.3427 - acc: 0.8430 - val_loss: 0.2078 - val_acc: 0.9712
# Epoch 11/35
# 1759/1759 [==============================] - 4s 2ms/step - loss: 0.3397 - acc: 0.8439 - val_loss: 0.1921 - val_acc: 0.9739
# Epoch 12/35
# 1759/1759 [==============================] - 3s 2ms/step - loss: 0.3372 - acc: 0.8447 - val_loss: 0.1737 - val_acc: 0.9824
# Epoch 13/35
# 1759/1759 [==============================] - 3s 2ms/step - loss: 0.3357 - acc: 0.8449 - val_loss: 0.1872 - val_acc: 0.9743
# Epoch 14/35
# 1759/1759 [==============================] - 4s 2ms/step - loss: 0.3347 - acc: 0.8451 - val_loss: 0.2030 - val_acc: 0.9707
# Epoch 15/35
# 1759/1759 [==============================] - 3s 2ms/step - loss: 0.3337 - acc: 0.8446 - val_loss: 0.1950 - val_acc: 0.9592
# Epoch 16/35
# 1759/1759 [==============================] - 4s 2ms/step - loss: 0.3334 - acc: 0.8455 - val_loss: 0.2367 - val_acc: 0.9637
# Epoch 17/35
# 1759/1759 [==============================] - 3s 2ms/step - loss: 0.3330 - acc: 0.8457 - val_loss: 0.1595 - val_acc: 0.9765
# Epoch 18/35
# 1759/1759 [==============================] - 3s 2ms/step - loss: 0.3326 - acc: 0.8460 - val_loss: 0.1766 - val_acc: 0.9846
# Epoch 19/35
# 1759/1759 [==============================] - 3s 2ms/step - loss: 0.3323 - acc: 0.8464 - val_loss: 0.1981 - val_acc: 0.9735
# Epoch 20/35
# 1759/1759 [==============================] - 3s 2ms/step - loss: 0.3320 - acc: 0.8459 - val_loss: 0.1887 - val_acc: 0.9733
# Epoch 21/35
# 1759/1759 [==============================] - 3s 2ms/step - loss: 0.3316 - acc: 0.8461 - val_loss: 0.1727 - val_acc: 0.9779
# Epoch 22/35
# 1759/1759 [==============================] - 4s 3ms/step - loss: 0.3317 - acc: 0.8457 - val_loss: 0.1817 - val_acc: 0.9775
# Epoch 23/35
# 1759/1759 [==============================] - 5s 3ms/step - loss: 0.3316 - acc: 0.8466 - val_loss: 0.2054 - val_acc: 0.9562
# Epoch 24/35
# 1759/1759 [==============================] - 4s 2ms/step - loss: 0.3313 - acc: 0.8459 - val_loss: 0.2217 - val_acc: 0.9541
# Epoch 25/35
# 1759/1759 [==============================] - 5s 3ms/step - loss: 0.3308 - acc: 0.8469 - val_loss: 0.1905 - val_acc: 0.9680
# Epoch 26/35
# 1759/1759 [==============================] - 3s 2ms/step - loss: 0.3310 - acc: 0.8456 - val_loss: 0.1784 - val_acc: 0.9706
# Epoch 27/35
# 1759/1759 [==============================] - 3s 1ms/step - loss: 0.3308 - acc: 0.8458 - val_loss: 0.2045 - val_acc: 0.9455
# Epoch 28/35
# 1759/1759 [==============================] - 2s 1ms/step - loss: 0.3309 - acc: 0.8456 - val_loss: 0.1851 - val_acc: 0.9549
# Epoch 29/35
# 1759/1759 [==============================] - 3s 2ms/step - loss: 0.3302 - acc: 0.8456 - val_loss: 0.1743 - val_acc: 0.9859
# Epoch 30/35
# 1759/1759 [==============================] - 3s 2ms/step - loss: 0.3300 - acc: 0.8465 - val_loss: 0.2074 - val_acc: 0.9496
# Epoch 31/35
# 1759/1759 [==============================] - 3s 2ms/step - loss: 0.3298 - acc: 0.8461 - val_loss: 0.1934 - val_acc: 0.9675
# Epoch 32/35
# 1759/1759 [==============================] - 3s 2ms/step - loss: 0.3295 - acc: 0.8470 - val_loss: 0.1904 - val_acc: 0.9592
# Epoch 33/35
# 1759/1759 [==============================] - 3s 2ms/step - loss: 0.3293 - acc: 0.8469 - val_loss: 0.1930 - val_acc: 0.9586
# Epoch 34/35
# 1759/1759 [==============================] - 2s 1ms/step - loss: 0.3291 - acc: 0.8476 - val_loss: 0.1702 - val_acc: 0.9830
# Epoch 35/35
# 1759/1759 [==============================] - 2s 1ms/step - loss: 0.3287 - acc: 0.8478 - val_loss: 0.1888 - val_acc: 0.9805

# %%
_, ax = plt.subplots(1, 2, figsize=(10, 5), dpi=100)
ax[0].plot(history.history['acc'], 'r')
ax[0].plot(history.history['val_acc'], 'g')
ax[0].set_xlabel("Num of Epochs")
ax[0].set_ylabel("Accuracy")
ax[0].set_title("Training Accuracy vs Validation Accuracy")
ax[0].legend(['train', 'validation'])

ax[1].plot(history.history['loss'], 'r')
ax[1].plot(history.history['val_loss'], 'g')
ax[1].set_xlabel("Num of Epochs")
ax[1].set_ylabel("Loss")
ax[1].set_title("Training Loss vs Validation Loss")
ax[1].legend(['train', 'validation'])

plt.tight_layout()

# %% [markdown]
# ## Test it
#
# ### Predict train data
#
# Rebuild model until epoch x.

# %%
model = models.Sequential()
model.add(layers.Dense(2, activation='relu', input_shape=(2,)))
model.add(layers.Dense(25, activation='relu'))
model.add(layers.Dense(2, activation='softmax'))
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['acc'])
history = model.fit(dftrain_x, dftrain_y, epochs=x, validation_split=0.1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 8
#       4 model.add(layers.Dense(2, activation='softmax'))
#       5 model.compile(optimizer='adam',
#       6               loss='categorical_crossentropy',
#       7               metrics=['acc'])
# ----> 8 history = model.fit(dftrain_x, dftrain_y, epochs=x, validation_split=0.1)
#
# NameError: name 'x' is not defined

# %%
y_hat = model.predict(x=dftrain_x)

# %%
y_pred_label = np.argmax(y_hat, axis=1)
y_true_label = np.argmax(dftrain_y, axis=1)

# %%
table = pd.crosstab(y_pred_label, y_true_label)
table

# %%
(table[0][0] + table[1][1]) / np.sum(table.sum())

# %% [markdown]
# ### Predict test data

# %%
predictions = model.predict(x=dftest_x)
pred_label = np.argmax(predictions, axis=1)
true_label = np.argmax(dftest_y, axis=1)

# %%
table = pd.crosstab(pred_label, true_label)
table

# %%
aux = np.abs(pred_label - true_label)
fails = np.count_nonzero(aux)

score = (len(aux) - fails) / len(aux)
score
