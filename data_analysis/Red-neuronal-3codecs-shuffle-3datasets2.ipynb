# %% [markdown]
# Nou còdec: zlib
#
# Còdecs: blosclz, zstd i zlib
#
# CONCLUSIONS: no es solapen cap dels tres

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np
import aux_funcs
from pathlib import Path

# %% [markdown]
# ## Collect data from 3 different containers
#
# 30: entropy shuffle (no split)
#
# 0: blosclz shuffle split
#
# 1: zstd shuffle split
#
# 2: zlib shuffle split

# %%
paths = [Path('../data_inputs_temp/'),
         Path('../data_inputs'),
         Path('../data_inputs_wind/')]

files = ['entropy-shuffle', 'blosclz-shuffle-split',
         'zstd-shuffle-split', 'zlib-shuffle-split']
categories = ["30", "0", "1", "2"]

df_entropy = aux_funcs.get_df_by_category(paths, files[0], categories[0])
df_blosclz = aux_funcs.get_df_by_category(paths, files[1], categories[1])
df_zstd = aux_funcs.get_df_by_category(paths, files[2], categories[2])
df_zlib = aux_funcs.get_df_by_category(paths, files[3], categories[3])

# %% [markdown]
# # Filter data
#
# Delete data corresponding to special values chunks.

# %%
df_shuffle = pd.concat([df_blosclz, df_zstd, df_zlib, df_entropy], axis=1)
df_shuffle = aux_funcs.delete_special_vals(df_shuffle, ["special_vals0", "special_vals1",
                                                        "special_vals2", "special_vals30"])
df_input_x = df_shuffle.iloc[:, [9, 10]]

# %% [markdown]
# ## Compute best category

# %%
df_codecs = df_shuffle.drop(['cratio30', 'speed30', 'special_vals30', 'special_vals0', 'special_vals1', 'special_vals2'], axis=1)

# %% [markdown]
# ### Normalize cratio and speed

# %%
dfcratios = pd.concat([df_codecs.iloc[:, 0], df_codecs.iloc[:, 2],
                       df_codecs.iloc[:, 4]], axis=0)
mean_cratio = dfcratios.mean()

cratio0 = df_codecs["cratio0"]
cratio1 = df_codecs["cratio1"]
cratio2 = df_codecs["cratio2"]

ncratio0 = cratio0 - mean_cratio
ncratio1 = cratio1 - mean_cratio
ncratio2 = cratio2 - mean_cratio

all_cratios = np.concatenate((ncratio0, ncratio1, ncratio2), axis=0)

std_cratio = all_cratios.std()
ncratio0 /= std_cratio
ncratio1 /= std_cratio
ncratio2 /= std_cratio

# %%
dfspeeds = pd.concat([df_codecs.iloc[:, 1], df_codecs.iloc[:, 3],
                      df_codecs.iloc[:, 5]], axis=0)
mean_speed = dfspeeds.mean()

speed0 = df_codecs["speed0"]
speed1 = df_codecs["speed1"]
speed2 = df_codecs["speed2"]

nspeed0 = speed0 - mean_speed
nspeed1 = speed1 - mean_speed
nspeed2 = speed2 - mean_speed

all_speeds = np.concatenate((nspeed0, nspeed1, nspeed2), axis=0)

dsv_speed = all_speeds.std()
nspeed0 /= dsv_speed
nspeed1 /= dsv_speed
nspeed2 /= dsv_speed

# %% [markdown]
# ### Compute score to determine which category is the best one

# %%
theta = 0.95

df_score = pd.DataFrame()
df_score.insert(0, 0, theta*ncratio0 + (1-theta)*nspeed0)
df_score.insert(1, 1, theta*ncratio1 + (1-theta)*nspeed1)
df_score.insert(2, 2, theta*ncratio2 + (1-theta)*nspeed2)

# %%
best_categ_shuffle = pd.DataFrame(df_score.idxmax(axis=1), columns=['best_categ'])

# %%
categories = best_categ_shuffle['best_categ'].unique()
if len(categories) < (len(files) - 1):
    raise ValueError("To train the data at least two possible categories must be provided")

# %%
df_t = pd.DataFrame()
df_t = pd.concat([df_t, df_input_x['cratio30']], axis=1)
df_t = pd.concat([df_t, df_input_x['speed30']], axis=1)
df_t = pd.concat([df_t, best_categ_shuffle], axis=1)

# %% [markdown]
# ## Split data into training and test
#
# Create a balanced training data with same amount of samples for each (best) category

# %%
df_blc = pd.DataFrame()
df_test = pd.DataFrame()
nsamples = min(len(df_t[df_t['best_categ'] == categories[0]]),
               len(df_t[df_t['best_categ'] == categories[1]]),
               len(df_t[df_t['best_categ'] == categories[2]])) - 2000
if nsamples <= 0:
    raise RuntimeError("not enough data")
for i in categories:
    df_i = df_t[df_t['best_categ'] == i]
    df_blc = pd.concat([df_blc, df_i.head(n=nsamples)], axis=0)
    df_test = pd.concat([df_test, df_i.iloc[nsamples:, :]], axis=0)

# %%
dftrain_y = df_blc['best_categ']
dftrain_x = df_blc.drop(['best_categ'], axis=1)

# %%
dftest_y = df_test['best_categ']
dftest_x = df_test.drop(['best_categ'], axis=1)

# %% [markdown]
# ## Normalize entropy data

# %%
dfcratios = dftrain_x.iloc[:, 0]
mean_cratio = dfcratios.mean()

cratio = dftrain_x["cratio30"]
cratio_mean = cratio.mean()
ncratio = cratio - cratio_mean
dsv_cratio = ncratio.std()
ncratio /= dsv_cratio

# %%
dfspeeds = dftrain_x.iloc[:, 1]
mean_speed = dfspeeds.mean()

speed = dftrain_x["speed30"]
speed_mean = speed.mean()
nspeed = speed - speed_mean
dvs_speed = nspeed.std()
nspeed /= dvs_speed

# %%
dftrain_x_norm = pd.DataFrame()
dftrain_x_norm.insert(0, "ncratio", ncratio)
dftrain_x_norm.insert(1, "nspeed", nspeed)
dftrain_x = dftrain_x_norm

# Normalize test data with train statistics
cratio_test = dftest_x["cratio30"]
speed_test = dftest_x["speed30"]
ncratio_test = cratio_test - cratio_mean
ncratio_test /= dsv_cratio
nspeed_test = speed_test - speed_mean
nspeed_test /= dvs_speed

dftest_x_norm = pd.DataFrame()
dftest_x_norm.insert(0, "ncratio", ncratio_test)
dftest_x_norm.insert(1, "nspeed", nspeed_test)

# %% [markdown]
# # Neural Network with 3 categories
#
# ## Build model

# %%
from keras.utils import to_categorical
dftrain_y = to_categorical(dftrain_y)
dftest_y = to_categorical(dftest_y)
# Out:
# 2023-01-03 08:14:09.554469: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from keras import models, layers
import tensorflow

tensorflow.random.set_seed(100)

model = models.Sequential()
model.add(layers.Dense(2, activation='relu', input_shape=(2,)))
model.add(layers.Dense(25, activation='relu'))
model.add(layers.Dense(3, activation='softmax'))
# Out:
# 2023-01-03 08:14:18.145591: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['acc'])

# %% [markdown]
#
# Epoch 20/35
# 995/995 [==============================] - 4s 4ms/step - loss: 0.4735 - acc: 0.7827 - val_loss: 8.9972 - val_acc: 0.6224
# Epoch 21/35
# 995/995 [==============================] - 2s 2ms/step - loss: 0.4736 - acc: 0.7829 - val_loss: 8.9776 - val_acc: 0.6543
# Epoch 22/35
# 995/995 [==============================] - 2s 2ms/step - loss: 0.4720 - acc: 0.7826 - val_loss: 9.0026 - val_acc: 0.6806
# Epoch 23/35
# 995/995 [==============================] - 3s 3ms/step - loss: 0.4721 - acc: 0.7836 - val_loss: 9.3489 - val_acc: 0.6148
# Epoch 24/35
# 995/995 [==============================] - 3s 3ms/step - loss: 0.4727 - acc: 0.7836 - val_loss: 9.1573 - val_acc: 0.6812
# Epoch 25/35
# 995/995 [==============================] - 3s 3ms/step - loss: 0.4719 - acc: 0.7835 - val_loss: 9.2882 - val_acc: 0.6634
# Epoch 26/35
# 995/995 [==============================] - 3s 3ms/step - loss: 0.4717 - acc: 0.7826 - val_loss: 9.4889 - val_acc: 0.6300
# Epoch 27/35
# 995/995 [==============================] - 2s 2ms/step - loss: 0.4712 - acc: 0.7826 - val_loss: 9.4440 - val_acc: 0.6543
# Epoch 28/35
# 995/995 [==============================] - 2s 2ms/step - loss: 0.4708 - acc: 0.7844 - val_loss: 9.3165 - val_acc: 0.6990
# Epoch 29/35
# 995/995 [==============================] - 3s 3ms/step - loss: 0.4714 - acc: 0.7844 - val_loss: 9.5235 - val_acc: 0.6586
# Epoch 30/35
# 995/995 [==============================] - 3s 3ms/step - loss: 0.4701 - acc: 0.7830 - val_loss: 9.6482 - val_acc: 0.6425
# Epoch 31/35
# 995/995 [==============================] - 2s 2ms/step - loss: 0.4698 - acc: 0.7838 - val_loss: 9.7712 - val_acc: 0.6204
# Epoch 32/35
# 995/995 [==============================] - 3s 3ms/step - loss: 0.4698 - acc: 0.7831 - val_loss: 9.4706 - val_acc: 0.6964
# Epoch 33/35
# 995/995 [==============================] - 2s 2ms/step - loss: 0.4696 - acc: 0.7840 - val_loss: 9.6946 - val_acc: 0.6580
# Epoch 34/35
# 995/995 [==============================] - 2s 2ms/step - loss: 0.4686 - acc: 0.7845 - val_loss: 9.6932 - val_acc: 0.6645
# Epoch 35/35
# 995/995 [==============================] - 3s 3ms/step - loss: 0.4700 - acc: 0.7840 - val_loss: 9.8704 - val_acc: 0.6331

# %%
_, ax = plt.subplots(1, 2, figsize=(10, 5), dpi=100)
ax[0].plot(history.history['acc'], 'r')
ax[0].plot(history.history['val_acc'], 'g')
ax[0].set_xlabel("Num of Epochs")
ax[0].set_ylabel("Accuracy")
ax[0].set_title("Training Accuracy vs Validation Accuracy")
ax[0].legend(['train', 'validation'])

ax[1].plot(history.history['loss'], 'r')
ax[1].plot(history.history['val_loss'], 'g')
ax[1].set_xlabel("Num of Epochs")
ax[1].set_ylabel("Loss")
ax[1].set_title("Training Loss vs Validation Loss")
ax[1].legend(['train', 'validation'])

plt.tight_layout()

# %% [markdown]
# ## Test it
#
# ### Predict train data
#
# Rebuild model until epoch x.

# %%
model = models.Sequential()
model.add(layers.Dense(2, activation='relu', input_shape=(2,)))
model.add(layers.Dense(25, activation='relu'))
model.add(layers.Dense(3, activation='softmax'))
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['acc'])
history = model.fit(dftrain_x, dftrain_y, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 995/995 [==============================] - 4s 2ms/step - loss: 0.8061 - acc: 0.6082 - val_loss: 1.5943 - val_acc: 0.4505
# Epoch 2/10
# 995/995 [==============================] - 3s 3ms/step - loss: 0.7254 - acc: 0.6446 - val_loss: 1.6744 - val_acc: 0.5147
# Epoch 3/10
# 995/995 [==============================] - 2s 2ms/step - loss: 0.7103 - acc: 0.6516 - val_loss: 1.9700 - val_acc: 0.4655
# Epoch 4/10
# 995/995 [==============================] - 2s 2ms/step - loss: 0.6884 - acc: 0.6638 - val_loss: 2.2735 - val_acc: 0.5014
# Epoch 5/10
# 995/995 [==============================] - 2s 2ms/step - loss: 0.6503 - acc: 0.6880 - val_loss: 2.9845 - val_acc: 0.4975
# Epoch 6/10
# 995/995 [==============================] - 2s 2ms/step - loss: 0.5880 - acc: 0.7456 - val_loss: 3.9008 - val_acc: 0.7176
# Epoch 7/10
# 995/995 [==============================] - 2s 2ms/step - loss: 0.5313 - acc: 0.7662 - val_loss: 5.4627 - val_acc: 0.6840
# Epoch 8/10
# 995/995 [==============================] - 2s 2ms/step - loss: 0.5051 - acc: 0.7723 - val_loss: 6.9049 - val_acc: 0.6484
# Epoch 9/10
# 995/995 [==============================] - 3s 3ms/step - loss: 0.4927 - acc: 0.7749 - val_loss: 7.8914 - val_acc: 0.6916
# Epoch 10/10
# 995/995 [==============================] - 3s 3ms/step - loss: 0.4866 - acc: 0.7762 - val_loss: 8.8844 - val_acc: 0.6673

# %%
y_hat = model.predict(x=dftrain_x)
y_pred_label = np.argmax(y_hat, axis=1)
y_true_label = np.argmax(dftrain_y, axis=1)
# Out:
# 1106/1106 [==============================] - 2s 2ms/step

# %%
table = pd.crosstab(y_pred_label, y_true_label)
table
# Out:
# col_0      0     1     2
# row_0
# 0      10373     4  1089
# 1        304  9109  3039
# 2       1114  2678  7663

# %%
(table[0][0] + table[1][1] + table[2][2]) / np.sum(table.sum())
# Out:
# 0.7673932095100783

# %% [markdown]
# ### Predict test data

# %%
predictions = model.predict(x=dftest_x)
pred_label = np.argmax(predictions, axis=1)
true_label = np.argmax(dftest_y, axis=1)
# Out:
# 1330/1330 [==============================] - 2s 1ms/step

# %%
table = pd.crosstab(pred_label, true_label)
table
# Out:
# col_0      0      1     2
# row_0
# 1      10951  29601  2000

# %%
aux = np.abs(pred_label - true_label)
fails = np.count_nonzero(aux)

score = (len(aux) - fails) / len(aux)
score
# Out:
# 0.6956429780033841
