# %% [markdown]
# Nou còdec: zlib
#
# Còdecs: blosclz, zstd i lz4hc
#
# CONCLUSIONS: zstd sempre és millor que lz4hc. Llevem zstd
#
# Còdecs: blosclz i lz4hc

# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import numpy as np
import aux_funcs
from pathlib import Path

# %% [markdown]
# ## Collect data from 3 different containers
#
# 30: entropy shuffle (no split)
#
# 0: blosclz shuffle split
#
# 1: lz4hc shuffle split

# %%
paths = [Path('../data_inputs_temp/'),
         Path('../data_inputs'),
         Path('../data_inputs_wind/')]

files = ['entropy-shuffle', 'blosclz-shuffle-split', 'lz4hc-shuffle-split']
categories = ["30", "0", "1"]

df_entropy = aux_funcs.get_df_by_category(paths, files[0], categories[0])
df_blosclz = aux_funcs.get_df_by_category(paths, files[1], categories[1])
df_lz4hc = aux_funcs.get_df_by_category(paths, files[2], categories[2])

# %% [markdown]
# # Filter data
#
# Delete data corresponding to special values chunks.

# %%
df_shuffle = pd.concat([df_blosclz, df_lz4hc, df_entropy], axis=1)
df_shuffle = aux_funcs.delete_special_vals(df_shuffle, ["special_vals0", "special_vals1", "special_vals30"])
df_input_x = df_shuffle.iloc[:, [6, 7]]

# %% [markdown]
# ## Compute best category

# %%
df_codecs = df_shuffle.drop(['cratio30', 'speed30', 'special_vals30', 'special_vals0', 'special_vals1'], axis=1)

# %% [markdown]
# ### Normalize cratio and speed

# %%
dfcratios = pd.concat([df_codecs.iloc[:, 0], df_codecs.iloc[:, 2]], axis=0)
mean_cratio = dfcratios.mean()

cratio0 = df_codecs["cratio0"]
cratio1 = df_codecs["cratio1"]

ncratio0 = cratio0 - mean_cratio
ncratio1 = cratio1 - mean_cratio
all_cratios = np.concatenate((ncratio0, ncratio1), axis=0)

std_cratio = all_cratios.std()
ncratio0 /= std_cratio
ncratio1 /= std_cratio

# %%
dfspeeds = pd.concat([df_codecs.iloc[:, 1], df_codecs.iloc[:, 3]], axis =0)
mean_speed = dfspeeds.mean()

speed0 = df_codecs["speed0"]
speed1 = df_codecs["speed1"]

nspeed0 = speed0 - mean_speed
nspeed1 = speed1 - mean_speed
all_speeds = np.concatenate((nspeed0, nspeed1), axis=0)

dsv_speed = all_speeds.std()
nspeed0 /= dsv_speed
nspeed1 /= dsv_speed

# %% [markdown]
# ### Compute score to determine which category is the best one

# %%
theta = 0.89

df_score = pd.DataFrame()
df_score.insert(0, 0, theta*ncratio0 + (1-theta)*nspeed0)
df_score.insert(1, 1, theta*ncratio1 + (1-theta)*nspeed1)

# %%
best_categ_shuffle = pd.DataFrame(df_score.idxmax(axis=1), columns=['best_categ'])

# %%
categories = best_categ_shuffle['best_categ'].unique()
if len(categories) <= 1:
    raise ValueError("To train the data at least two possible categories must be provided")

# %%
df_t = pd.DataFrame()
df_t = pd.concat([df_t, df_input_x['cratio30']], axis = 1)
df_t = pd.concat([df_t, df_input_x['speed30']], axis = 1)
df_t = pd.concat([df_t, best_categ_shuffle], axis = 1)

# %% [markdown]
# ## Split data into training and test
#
# Create a balanced training data with same amount of samples for each (best) category

# %%
df_blc = pd.DataFrame()
df_test = pd.DataFrame()
nsamples = min(len(df_t[df_t['best_categ'] == categories[0]]),
               len(df_t[df_t['best_categ'] == categories[1]])) - 2000
if nsamples <= 0:
    raise RuntimeError("not enough data")
for i in categories:
    df_i = df_t[df_t['best_categ'] == i]
    df_blc = pd.concat([df_blc, df_i.head(n=nsamples)], axis=0)
    df_test = pd.concat([df_test, df_i.iloc[nsamples:, :]], axis=0)

# %%
dftrain_y = df_blc['best_categ']
dftrain_x = df_blc.drop(['best_categ'], axis=1)

# %%
dftest_y = df_test['best_categ']
dftest_x = df_test.drop(['best_categ'], axis=1)

# %% [markdown]
# ## Normalize entropy data

# %%
dfcratios = dftrain_x.iloc[:, 0]
mean_cratio = dfcratios.mean()

cratio = dftrain_x["cratio30"]
cratio_mean = cratio.mean()
ncratio = cratio - cratio_mean
dsv_cratio = ncratio.std()
ncratio /= dsv_cratio

# %%
dfspeeds = dftrain_x.iloc[:, 1]
mean_speed = dfspeeds.mean()

speed = dftrain_x["speed30"]
speed_mean = speed.mean()
nspeed = speed - speed_mean
dvs_speed = nspeed.std()
nspeed /= dvs_speed

# %%
dftrain_x_norm = pd.DataFrame()
dftrain_x_norm.insert(0, "ncratio", ncratio)
dftrain_x_norm.insert(1, "nspeed", nspeed)
dftrain_x = dftrain_x_norm

# Normalize test data with train statistics
cratio_test = dftest_x["cratio30"]
speed_test = dftest_x["speed30"]
ncratio_test = cratio_test - cratio_mean
ncratio_test /= dsv_cratio
nspeed_test = speed_test - speed_mean
nspeed_test /= dvs_speed

dftest_x_norm = pd.DataFrame()
dftest_x_norm.insert(0, "ncratio", ncratio_test)
dftest_x_norm.insert(1, "nspeed", nspeed_test)

# %% [markdown]
# # Neural Network with 2 categories
#
# ## Build model

# %%
from keras.utils import to_categorical
dftrain_y = to_categorical(dftrain_y)
dftest_y = to_categorical(dftest_y)
# Out:
# 2023-01-02 10:40:05.546761: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from keras import models, layers
import tensorflow

tensorflow.random.set_seed(100)

model = models.Sequential()
model.add(layers.Dense(2, activation='relu', input_shape=(2,)))
model.add(layers.Dense(25, activation='relu'))
model.add(layers.Dense(2, activation='softmax'))
# Out:
# 2023-01-02 10:40:10.795390: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['acc'])

# %% [markdown]
# ## Train it with data

# %%
history = model.fit(dftrain_x, dftrain_y, epochs=35, validation_split=0.1)
# Out:
# Epoch 1/35
# 1498/1498 [==============================] - 4s 2ms/step - loss: 0.5181 - acc: 0.7292 - val_loss: 0.5480 - val_acc: 0.7582
# Epoch 2/35
# 1498/1498 [==============================] - 3s 2ms/step - loss: 0.4667 - acc: 0.7608 - val_loss: 0.5529 - val_acc: 0.7498
# Epoch 3/35
# 1498/1498 [==============================] - 3s 2ms/step - loss: 0.4595 - acc: 0.7672 - val_loss: 0.5193 - val_acc: 0.8085
# Epoch 4/35
# 1498/1498 [==============================] - 3s 2ms/step - loss: 0.4529 - acc: 0.7763 - val_loss: 0.5280 - val_acc: 0.8070
# Epoch 5/35
# 1498/1498 [==============================] - 2s 2ms/step - loss: 0.4451 - acc: 0.7861 - val_loss: 0.5551 - val_acc: 0.7537
# Epoch 6/35
# 1498/1498 [==============================] - 3s 2ms/step - loss: 0.4363 - acc: 0.8008 - val_loss: 0.4549 - val_acc: 0.9441
# Epoch 7/35
# 1498/1498 [==============================] - 3s 2ms/step - loss: 0.4257 - acc: 0.8168 - val_loss: 0.5051 - val_acc: 0.8656
# Epoch 8/35
# 1498/1498 [==============================] - 5s 3ms/step - loss: 0.4119 - acc: 0.8359 - val_loss: 0.4025 - val_acc: 0.9735
# Epoch 9/35
# 1498/1498 [==============================] - 3s 2ms/step - loss: 0.3929 - acc: 0.8545 - val_loss: 0.5101 - val_acc: 0.9337
# Epoch 10/35
# 1498/1498 [==============================] - 3s 2ms/step - loss: 0.3636 - acc: 0.8670 - val_loss: 0.2995 - val_acc: 0.9675
# Epoch 11/35
# 1498/1498 [==============================] - 4s 2ms/step - loss: 0.3266 - acc: 0.8834 - val_loss: 0.2576 - val_acc: 0.9563
# Epoch 12/35
# 1498/1498 [==============================] - 3s 2ms/step - loss: 0.2975 - acc: 0.8960 - val_loss: 0.1761 - val_acc: 0.9529
# Epoch 13/35
# 1498/1498 [==============================] - 4s 3ms/step - loss: 0.2815 - acc: 0.9012 - val_loss: 0.1446 - val_acc: 0.9534
# Epoch 14/35
# 1498/1498 [==============================] - 3s 2ms/step - loss: 0.2727 - acc: 0.9036 - val_loss: 0.1485 - val_acc: 0.9403
# Epoch 15/35
# 1498/1498 [==============================] - 2s 2ms/step - loss: 0.2689 - acc: 0.9044 - val_loss: 0.1268 - val_acc: 0.9469
# Epoch 16/35
# 1498/1498 [==============================] - 2s 1ms/step - loss: 0.2663 - acc: 0.9047 - val_loss: 0.1459 - val_acc: 0.9350
# Epoch 17/35
# 1498/1498 [==============================] - 3s 2ms/step - loss: 0.2643 - acc: 0.9065 - val_loss: 0.1080 - val_acc: 0.9555
# Epoch 18/35
# 1498/1498 [==============================] - 3s 2ms/step - loss: 0.2633 - acc: 0.9064 - val_loss: 0.1112 - val_acc: 0.9544
# Epoch 19/35
# 1498/1498 [==============================] - 2s 2ms/step - loss: 0.2622 - acc: 0.9073 - val_loss: 0.0985 - val_acc: 0.9598
# Epoch 20/35
# 1498/1498 [==============================] - 3s 2ms/step - loss: 0.2627 - acc: 0.9071 - val_loss: 0.0974 - val_acc: 0.9611
# Epoch 21/35
# 1498/1498 [==============================] - 3s 2ms/step - loss: 0.2626 - acc: 0.9064 - val_loss: 0.0992 - val_acc: 0.9596
# Epoch 22/35
# 1498/1498 [==============================] - 3s 2ms/step - loss: 0.2618 - acc: 0.9069 - val_loss: 0.1150 - val_acc: 0.9489
# Epoch 23/35
# 1498/1498 [==============================] - 2s 2ms/step - loss: 0.2621 - acc: 0.9067 - val_loss: 0.1491 - val_acc: 0.9315
# Epoch 24/35
# 1498/1498 [==============================] - 2s 2ms/step - loss: 0.2614 - acc: 0.9069 - val_loss: 0.1037 - val_acc: 0.9546
# Epoch 25/35
# 1498/1498 [==============================] - 3s 2ms/step - loss: 0.2613 - acc: 0.9074 - val_loss: 0.1240 - val_acc: 0.9409
# Epoch 26/35
# 1498/1498 [==============================] - 3s 2ms/step - loss: 0.2611 - acc: 0.9073 - val_loss: 0.1194 - val_acc: 0.9450
# Epoch 27/35
# 1498/1498 [==============================] - 4s 2ms/step - loss: 0.2630 - acc: 0.9066 - val_loss: 0.1367 - val_acc: 0.9369
# Epoch 28/35
# 1498/1498 [==============================] - 3s 2ms/step - loss: 0.2613 - acc: 0.9071 - val_loss: 0.1587 - val_acc: 0.9290
# Epoch 29/35
# 1498/1498 [==============================] - 3s 2ms/step - loss: 0.2613 - acc: 0.9077 - val_loss: 0.1559 - val_acc: 0.9298
# Epoch 30/35
# 1498/1498 [==============================] - 3s 2ms/step - loss: 0.2614 - acc: 0.9071 - val_loss: 0.1223 - val_acc: 0.9403
# Epoch 31/35
# 1498/1498 [==============================] - 3s 2ms/step - loss: 0.2615 - acc: 0.9067 - val_loss: 0.1081 - val_acc: 0.9501
# Epoch 32/35
# 1498/1498 [==============================] - 3s 2ms/step - loss: 0.2611 - acc: 0.9072 - val_loss: 0.1402 - val_acc: 0.9352
# Epoch 33/35
# 1498/1498 [==============================] - 3s 2ms/step - loss: 0.2615 - acc: 0.9074 - val_loss: 0.1437 - val_acc: 0.9324
# Epoch 34/35
# 1498/1498 [==============================] - 4s 3ms/step - loss: 0.2613 - acc: 0.9072 - val_loss: 0.1339 - val_acc: 0.9375
# Epoch 35/35
# 1498/1498 [==============================] - 5s 3ms/step - loss: 0.2617 - acc: 0.9067 - val_loss: 0.1212 - val_acc: 0.9416

# %%
_, ax = plt.subplots(1, 2, figsize=(10, 5), dpi=100)
ax[0].plot(history.history['acc'], 'r')
ax[0].plot(history.history['val_acc'], 'g')
ax[0].set_xlabel("Num of Epochs")
ax[0].set_ylabel("Accuracy")
ax[0].set_title("Training Accuracy vs Validation Accuracy")
ax[0].legend(['train', 'validation'])

ax[1].plot(history.history['loss'], 'r')
ax[1].plot(history.history['val_loss'], 'g')
ax[1].set_xlabel("Num of Epochs")
ax[1].set_ylabel("Loss")
ax[1].set_title("Training Loss vs Validation Loss")
ax[1].legend(['train', 'validation'])

plt.tight_layout()

# %% [markdown]
# ## Test it
#
# ### Predict train data
#
# Rebuild model until epoch x.

# %%
model = models.Sequential()
model.add(layers.Dense(2, activation='relu', input_shape=(2,)))
model.add(layers.Dense(25, activation='relu'))
model.add(layers.Dense(2, activation='softmax'))
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['acc'])
history = model.fit(dftrain_x, dftrain_y, epochs=10, validation_split=0.1)
# Out:
# Epoch 1/10
# 1498/1498 [==============================] - 4s 2ms/step - loss: 0.5209 - acc: 0.7399 - val_loss: 0.5427 - val_acc: 0.7954
# Epoch 2/10
# 1498/1498 [==============================] - 3s 2ms/step - loss: 0.4579 - acc: 0.7762 - val_loss: 0.5048 - val_acc: 0.8442
# Epoch 3/10
# 1498/1498 [==============================] - 3s 2ms/step - loss: 0.4526 - acc: 0.7779 - val_loss: 0.5015 - val_acc: 0.8316
# Epoch 4/10
# 1498/1498 [==============================] - 2s 1ms/step - loss: 0.4486 - acc: 0.7827 - val_loss: 0.5417 - val_acc: 0.7683
# Epoch 5/10
# 1498/1498 [==============================] - 2s 1ms/step - loss: 0.4444 - acc: 0.7866 - val_loss: 0.5491 - val_acc: 0.7678
# Epoch 6/10
# 1498/1498 [==============================] - 2s 2ms/step - loss: 0.4399 - acc: 0.7947 - val_loss: 0.4807 - val_acc: 0.8960
# Epoch 7/10
# 1498/1498 [==============================] - 2s 1ms/step - loss: 0.4355 - acc: 0.8011 - val_loss: 0.5296 - val_acc: 0.8057
# Epoch 8/10
# 1498/1498 [==============================] - 2s 1ms/step - loss: 0.4314 - acc: 0.8061 - val_loss: 0.4433 - val_acc: 0.9510
# Epoch 9/10
# 1498/1498 [==============================] - 2s 2ms/step - loss: 0.4275 - acc: 0.8132 - val_loss: 0.5142 - val_acc: 0.8417
# Epoch 10/10
# 1498/1498 [==============================] - 2s 2ms/step - loss: 0.4237 - acc: 0.8198 - val_loss: 0.4705 - val_acc: 0.9101

# %%
y_hat = model.predict(x=dftrain_x)
# Out:
# 1665/1665 [==============================] - 2s 1ms/step

# %%
y_pred_label = np.argmax(y_hat, axis=1)
y_true_label = np.argmax(dftrain_y, axis=1)

# %%
table = pd.crosstab(y_pred_label, y_true_label)
table
# Out:
# col_0      0      1
# row_0
# 0      23193   5738
# 1       3438  20893

# %%
(table[0][0] + table[1][1]) / np.sum(table.sum())
# Out:
# 0.8277195749314709

# %% [markdown]
# ### Predict test data

# %%
predictions = model.predict(x=dftest_x)
pred_label = np.argmax(predictions, axis=1)
true_label = np.argmax(dftest_y, axis=1)
# Out:
# 771/771 [==============================] - 1s 1ms/step

# %%
table = pd.crosstab(pred_label, true_label)
table
# Out:
# col_0     0      1
# row_0
# 1      2000  22663

# %%
aux = np.abs(pred_label - true_label)
fails = np.count_nonzero(aux)

score = (len(aux) - fails) / len(aux)
score
# Out:
# 0.9189068645339172
